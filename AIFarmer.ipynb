# %%
import pandas as pd 
import numpy as nm
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("https://raw.githubusercontent.com/upflairs-pvt-ltd/3rd_july_datascience/master/farmer_guider/farmer.csv")
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
df.tail()
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee

# %%
df['label'].value_counts()
# Out:
# label
# rice           100
# maize          100
# chickpea       100
# kidneybeans    100
# pigeonpeas     100
# mothbeans      100
# mungbean       100
# blackgram      100
# lentil         100
# pomegranate    100
# banana         100
# mango          100
# grapes         100
# watermelon     100
# muskmelon      100
# apple          100
# orange         100
# papaya         100
# coconut        100
# cotton         100
# jute           100
# coffee         100
# Name: count, dtype: int64

# %%
group = df.groupby('label')

# %%
group[['N']].mean()
# Out:
#                   N
# label
# apple         20.80
# banana       100.23
# blackgram     40.02
# chickpea      40.09
# coconut       21.98
# coffee       101.20
# cotton       117.77
# grapes        23.18
# jute          78.40
# kidneybeans   20.75
# lentil        18.77
# maize         77.76
# mango         20.07
# mothbeans     21.44
# mungbean      20.99
# muskmelon    100.32
# orange        19.58
# papaya        49.88
# pigeonpeas    20.73
# pomegranate   18.87
# rice          79.89
# watermelon    99.42

# %%
group[['temperature']].mean()
# Out:
#              temperature
# label
# apple          22.630942
# banana         27.376798
# blackgram      29.973340
# chickpea       18.872847
# coconut        27.409892
# coffee         25.540477
# cotton         23.988958
# grapes         23.849575
# jute           24.958376
# kidneybeans    20.115085
# lentil         24.509052
# maize          22.389204
# mango          31.208770
# mothbeans      28.194920
# mungbean       28.525775
# muskmelon      28.663066
# orange         22.765725
# papaya         33.723859
# pigeonpeas     27.741762
# pomegranate    21.837842
# rice           23.689332
# watermelon     25.591767

# %%
group[['N']].min()
# Out:
#                N
# label
# apple          0
# banana        80
# blackgram     20
# chickpea      20
# coconut        0
# coffee        80
# cotton       100
# grapes         0
# jute          60
# kidneybeans    0
# lentil         0
# maize         60
# mango          0
# mothbeans      0
# mungbean       0
# muskmelon     80
# orange         0
# papaya        31
# pigeonpeas     0
# pomegranate    0
# rice          60
# watermelon    80

# %%
group[['N']].max()
# Out:
#                N
# label
# apple         40
# banana       120
# blackgram     60
# chickpea      60
# coconut       40
# coffee       120
# cotton       140
# grapes        40
# jute         100
# kidneybeans   40
# lentil        40
# maize        100
# mango         40
# mothbeans     40
# mungbean      40
# muskmelon    120
# orange        40
# papaya        70
# pigeonpeas    40
# pomegranate   40
# rice          99
# watermelon   120

# %%
# Calculating mean, min, and max all together
result = group[['temperature']].agg(['mean', 'min', 'max'])
print(result)
# Out:
#             temperature
#                    mean        min        max
# label
# apple         22.630942  21.036527  23.996862
# banana        27.376798  25.010185  29.908885
# blackgram     29.973340  25.097374  34.946616
# chickpea      18.872847  17.024985  20.995022
# coconut       27.409892  25.008724  29.869083
# coffee        25.540477  23.059519  27.923744
# cotton        23.988958  22.000851  25.992374
# grapes        23.849575   8.825675  41.948657
# jute          24.958376  23.094338  26.985822
# kidneybeans   20.115085  15.330426  24.923601
# lentil        24.509052  18.064861  29.944139
# maize         22.389204  18.041855  26.549864
# mango         31.208770  27.003155  35.990097
# mothbeans     28.194920  24.018254  31.999286
# mungbean      28.525775  27.014704  29.914544
# muskmelon     28.663066  27.024151  29.943492
# orange        22.765725  10.010813  34.906653
# papaya        33.723859  23.012402  43.675493
# pigeonpeas    27.741762  18.319104  36.977944
# pomegranate   21.837842  18.071330  24.962732
# rice          23.689332  20.045414  26.929951
# watermelon    25.591767  24.043558  26.986037

# %%
result.index
# Out:
# Index(['apple', 'banana', 'blackgram', 'chickpea', 'coconut', 'coffee',
#        'cotton', 'grapes', 'jute', 'kidneybeans', 'lentil', 'maize', 'mango',
#        'mothbeans', 'mungbean', 'muskmelon', 'orange', 'papaya', 'pigeonpeas',
#        'pomegranate', 'rice', 'watermelon'],
#       dtype='object', name='label')

# %%
n=group['N'].agg(minimum= "min",maximum="max",average="mean")
n
# Out:
#              minimum  maximum  average
# label
# apple              0       40    20.80
# banana            80      120   100.23
# blackgram         20       60    40.02
# chickpea          20       60    40.09
# coconut            0       40    21.98
# coffee            80      120   101.20
# cotton           100      140   117.77
# grapes             0       40    23.18
# jute              60      100    78.40
# kidneybeans        0       40    20.75
# lentil             0       40    18.77
# maize             60      100    77.76
# mango              0       40    20.07
# mothbeans          0       40    21.44
# mungbean           0       40    20.99
# muskmelon         80      120   100.32
# orange             0       40    19.58
# papaya            31       70    49.88
# pigeonpeas         0       40    20.73
# pomegranate        0       40    18.87
# rice              60       99    79.89
# watermelon        80      120    99.42

# %%
result.reset_index(inplace=True)

# %%
min_temperature = group['temperature'].mean()
min_temperature.plot.bar(color='crimson')

plt.xlabel('Label')
plt.ylabel('Avg Temperature')
plt.title('Avg Temperature by Label')

plt.show()

# %%
min_temperature = group['temperature'].min()
min_temperature.plot.bar(color='blue')

plt.xlabel('Label')
plt.ylabel('min Temperature')
plt.title('min Temperature by Label')

plt.show()

# %%
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
x = df.drop('label', axis='columns')
x
# Out:
#         N   P   K  temperature   humidity        ph    rainfall
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340
# ...   ...  ..  ..          ...        ...       ...         ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041
#
# [2200 rows x 7 columns]

# %%
x.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
x.duplicated().sum()
# Out:
# np.int64(0)

# %%
x
# Out:
#         N   P   K  temperature   humidity        ph    rainfall
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340
# ...   ...  ..  ..          ...        ...       ...         ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041
#
# [2200 rows x 7 columns]

# %%
x.dtypes
# Out:
# N                int64
# P                int64
# K                int64
# temperature    float64
# humidity       float64
# ph             float64
# rainfall       float64
# dtype: object

# %%
sns.kdeplot(x['temperature'])
# Out:
# <Axes: xlabel='temperature', ylabel='Density'>

# %%
x.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340

# %%
from sklearn .preprocessing import StandardScaler

# %%
std_scaler = StandardScaler()
x_transformed = std_scaler.fit_transform(x)

# %%
x_transformed.shape
# Out:
# (2200, 7)

# %%
x_transformed
# Out:
# array([[ 1.0687974 , -0.34455075, -0.1016875 , ...,  0.47266646,
#          0.04330173,  1.8103605 ],
#        [ 0.93332887,  0.14061552, -0.14118477, ...,  0.39705125,
#          0.73487256,  2.24205791],
#        [ 0.25598625,  0.04964684, -0.08193887, ...,  0.48695381,
#          1.77151047,  2.92106603],
#        ...,
#        [ 1.82742114, -0.61745677, -0.35841972, ..., -0.19123516,
#         -0.13812031,  1.27141766],
#        [ 1.80032743, -0.64777967, -0.27942519, ..., -0.86951801,
#          0.37390383,  0.43154519],
#        [ 1.44810927, -1.07230015, -0.35841972, ..., -0.49802006,
#          0.40109573,  0.68200518]])

# %%
pd.DataFrame(x_transformed)
# Out:
#              0         1         2         3         4         5         6
# 0     1.068797 -0.344551 -0.101688 -0.935587  0.472666  0.043302  1.810361
# 1     0.933329  0.140616 -0.141185 -0.759646  0.397051  0.734873  2.242058
# 2     0.255986  0.049647 -0.081939 -0.515898  0.486954  1.771510  2.921066
# 3     0.635298 -0.556811 -0.160933  0.172807  0.389805  0.660308  2.537048
# 4     0.743673 -0.344551 -0.121436 -1.083647  0.454792  1.497868  2.898373
# ...        ...       ...       ...       ...       ...       ...       ...
# 2195  1.529390 -0.587134 -0.318922  0.228814 -0.227709  0.401395  1.352437
# 2196  1.312641 -1.163269 -0.417666  0.355720 -0.666947 -0.494413  0.445183
# 2197  1.827421 -0.617457 -0.358420 -0.293218 -0.191235 -0.138120  1.271418
# 2198  1.800327 -0.647780 -0.279425  0.129612 -0.869518  0.373904  0.431545
# 2199  1.448109 -1.072300 -0.358420 -0.397667 -0.498020  0.401096  0.682005
#
# [2200 rows x 7 columns]

# %%
sns.kdeplot(pd.DataFrame(x_transformed)[3])
plt.show()

# %%
sns.kdeplot(x['temperature'])
plt.show()

# %%
# ready to train the algorithm
from sklearn.cluster import KMeans

# %%
kmeans_obj = KMeans()

# %%
labels = kmeans_obj.fit_predict(x_transformed)  # algo trained and prediction
labels
# Out:
# array([6, 6, 6, ..., 6, 0, 0], dtype=int32)

# %%
set(labels)
# Out:
# {np.int32(0),
#  np.int32(1),
#  np.int32(2),
#  np.int32(3),
#  np.int32(4),
#  np.int32(5),
#  np.int32(6),
#  np.int32(7)}

# %%
labels.shape
# Out:
# (2200,)

# %%
x_transformed.shape
# Out:
# (2200, 7)

# %%
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
df['cluster_no'] = labels
df.head(40)
# Out:
#      N   P   K  temperature   humidity        ph    rainfall label  cluster_no
# 0   90  42  43    20.879744  82.002744  6.502985  202.935536  rice           6
# 1   85  58  41    21.770462  80.319644  7.038096  226.655537  rice           6
# 2   60  55  44    23.004459  82.320763  7.840207  263.964248  rice           6
# 3   74  35  40    26.491096  80.158363  6.980401  242.864034  rice           6
# 4   78  42  42    20.130175  81.604873  7.628473  262.717340  rice           6
# 5   69  37  42    23.058049  83.370118  7.073454  251.055000  rice           6
# 6   69  55  38    22.708838  82.639414  5.700806  271.324860  rice           6
# 7   94  53  40    20.277744  82.894086  5.718627  241.974195  rice           6
# 8   89  54  38    24.515881  83.535216  6.685346  230.446236  rice           6
# 9   68  58  38    23.223974  83.033227  6.336254  221.209196  rice           6
# 10  91  53  40    26.527235  81.417538  5.386168  264.614870  rice           6
# 11  90  46  42    23.978982  81.450616  7.502834  250.083234  rice           6
# 12  78  58  44    26.800796  80.886848  5.108682  284.436457  rice           6
# 13  93  56  36    24.014976  82.056872  6.984354  185.277339  rice           6
# 14  94  50  37    25.665852  80.663850  6.948020  209.586971  rice           6
# 15  60  48  39    24.282094  80.300256  7.042299  231.086335  rice           6
# 16  85  38  41    21.587118  82.788371  6.249051  276.655246  rice           6
# 17  91  35  39    23.793920  80.418180  6.970860  206.261186  rice           6
# 18  77  38  36    21.865252  80.192301  5.953933  224.555017  rice           6
# 19  88  35  40    23.579436  83.587603  5.853932  291.298662  rice           6
# 20  89  45  36    21.325042  80.474764  6.442475  185.497473  rice           6
# 21  76  40  43    25.157455  83.117135  5.070176  231.384316  rice           6
# 22  67  59  41    21.947667  80.973842  6.012633  213.356092  rice           6
# 23  83  41  43    21.052536  82.678395  6.254028  233.107582  rice           6
# 24  98  47  37    23.483813  81.332651  7.375483  224.058116  rice           6
# 25  66  53  41    25.075635  80.523891  7.778915  257.003887  rice           6
# 26  97  59  43    26.359272  84.044036  6.286500  271.358614  rice           6
# 27  97  50  41    24.529227  80.544986  7.070960  260.263403  rice           6
# 28  60  49  44    20.775761  84.497744  6.244841  240.081065  rice           6
# 29  84  51  35    22.301574  80.644165  6.043305  197.979121  rice           6
# 30  73  57  41    21.446540  84.943760  5.824709  272.201720  rice           6
# 31  92  35  40    22.179319  80.331272  6.357389  200.088279  rice           6
# 32  85  37  39    24.527837  82.736856  6.364135  224.675723  rice           6
# 33  98  53  38    20.267076  81.638952  5.014507  270.441727  rice           6
# 34  88  54  44    25.735429  83.882662  6.149411  233.132137  rice           6
# 35  95  55  42    26.795339  82.148087  5.950661  193.347399  rice           6
# 36  99  57  35    26.757542  81.177340  5.960370  272.299906  rice           6
# 37  95  39  36    23.863305  83.152508  5.561399  285.249365  rice           6
# 38  60  43  44    21.019447  82.952217  7.416245  298.401847  rice           6
# 39  63  44  41    24.172988  83.728757  5.583370  257.034355  rice           6

# %%
df[df['cluster_no'] == 6]['label'].unique()
# Out:
# array(['rice', 'pigeonpeas', 'papaya', 'coconut', 'jute', 'coffee'],
#       dtype=object)

# %%
df[df['cluster_no'] == 1]['label'].unique()
# Out:
# array(['chickpea', 'kidneybeans', 'pigeonpeas'], dtype=object)

# %%
import os,joblib
os.makedirs('models',exist_ok=True)
joblib.dump(std_scaler,'./models/std_scaler.lb')
joblib.dump(kmeans_obj,'./models/kmeans_model.lb')
# Out:
# ['./models/kmeans_model.lb']

# %%
df[['label','cluster_no']].to_csv("./models/filter_crops.csv",index=False)
